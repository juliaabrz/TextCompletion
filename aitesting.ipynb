# %%
####################
# import libraries #
####################

# tensorflow for keras and neural network
import tensorflow as tf
print ("TensorFlow version:", tf.__version__)

# keras neural network libraries
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense

# libraries for display widgets
from google.colab import widgets
import ipywidgets
from ipywidgets import Button
from IPython.display import display, clear_output

# numpy for dealing with arrays
import numpy as np

# FUNCTIONS:
# function that returns outputs from model
# potentially will have more functions from neural network

####################
#   Prepare Data   #
####################

# open lyric file with data
file = open("ts-all-songs.txt", "r", encoding = "utf8")
lines=[]


# CREATE DICTIONARY and prepare dataset
# add words to variable
for i in file:
  lines.append(i)

data = ' '.join(lines)

# remove any unnecessary characters - leaving in '\n', newline character will be useful to consider as its own word
data=data.replace('"','').replace(',','')
data = data.lower()

# remove any repeats - need to create index so only one of each word is needed
z = []
for w in data.split():
  if w not in z:
    z.append(w)

dictionary = ' '.join(z)

# use keras tokenizer to create a dictionary of all words
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts([dictionary])

print (dictionary)
# save the tokenizer for later - use pickle.dump()

# convert the lyrics to numbers based on dictionary index
sequence_data = tokenizer.texts_to_sequences([data])[0]

print (sequence_data)
# store sequences of words (previous three words + word) in a list
sequences = []

for i in range (1, len(sequence_data)):
  words = sequence_data [i-3:i+1]
  sequences.append (words)

print (sequences)
#sequences = np.array(sequences)

#scale inputs so that they are in between 0 and 1
scaler=MinMaxScaler()

scaler.fit(sequences[2:len(sequences)])
sequences=scaler.transform(sequences[2:len(sequences)])

print (sequences)

# create 3 input variables and 1 and output variable
x = []
y = []

count=0
# loop through each sequence
for i in sequences[2:len(sequences)]:
  # store previous 3 word in their own input variables, current word in output
  # this will be used for training
  x.append([])
  x[count].append(i[0])
  x[count].append(i[1])
  x[count].append(i[2])
  y.append(i[3])
  count+=1


#convert to numpy array
#x1 = np.array(x1)
#x2 = np.array(x2)
#x3 = np.array(x3)
#y = np.array (y)




# convert y to categorical - used for loss calculations
#y = tf.keras.utils.to_categorical(y, num_classes=len(tokenizer.word_index)+1)


################################################
#                MODEL TIME                    #
################################################

# outputs function

# split data figure out what data is training data and what is testing
train, test = train_test_split(data,test_size=0.2,random_state=1)
# call getOutputs function for train and test

# CREATE FUNCTIONAL API MODEL - NEURAL NETWORK using keras
# import necessary libraries from Keras
# create and define an input layer
inputLayer = Input (shape=(3,), name='inputLayer')
# connect the layers
# create hidden layers using dense
layer1 = Dense (1000, activation = "relu", name = 'layer1')(inputLayer)
layer2 = Dense (1000, activation = "relu", name = 'layer2')(layer1)
# create output layer
w1output = Dense(1, activation = "linear", name = 'w1output')(layer2)
# create branched layer for multiple outputs
branchedLayer1 = Dense (1000, activation = "relu", name = 'branchedLayer1')(layer2)
w2output = Dense (1, activation = "linear", name = 'w2output')(branchedLayer1)
branchedLayer2 = Dense (1000, activation = "relu", name = 'branchedLayer2')(layer2)
w3output = Dense (1, activation = "linear", name = 'w3output')(branchedLayer2)
# create and define a model using model class
model = Model(inputs=inputLayer, outputs = [w1output,w2output,w3output])
# display model summary for debugging - model.summary()
print (model.summary())

# import callbacks
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard
# modelCheckpoint used to store best weights
checkpoint = ModelCheckpoint('models.h5', monitor='loss',verbose=1, save_best_only=True,mode='auto' )
# Reduce learning rate used when the accuracy doesn't improve after 3 times through the dataset
reduceLR = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=5, min_lr=0.001, verbose=1)
#visualize loss
TBvisual=TensorBoard(log_dir='logs')

#compile the model
model.compile(optimizer='adam',loss={'w1output':'mse','w2output':'mse','w3output':'mse'})
model.fit(x, y, epochs=10, batch_size=64, callbacks=[checkpoint, reduceLR, TBvisual])

# train the model - fit it to pre-saved training data - should be one line using Keras
# save the best model

# evaluate the model for accuracy - only in debug/model preparation
# run predictions with test portion of data
predictions = model.predict(x)
word1=predictions[0]
word2=predictions[1]
word3=predictions[2]

for i in range (0,5):
  print (x[i],word1[i],word2[i],word3[i])
# in test program, will need to display accuracy
# Out:
# TensorFlow version: 2.7.0
# he said the way my blue eyes shined put those georgia stars to shame that night i that's a lie just boy in chevy truck had tendency of gettin' stuck on backroads at and was right there beside him all summer long then time we woke up find gone but when you think tim mcgraw hope favorite song one danced moon like spotlight lake happiness little black dress head your chest old faded jeans me september saw month tears thanking god weren't here see box beneath bed is letter never read from three summers back it's hard not it bittersweet lookin' nice believe i'm for first since standing street there's left doorstep thing you'll someday turn radio takes place oh mmm state obvious didn't get perfect fantasy realize love yourself more than could ever so go tell friends obsessive crazy fine won't mind if say by hate stupid pickup let drive you're redneck heartbreak who's really bad lying watch strike match wasted as far concerned another picture burn no sitting planning revenge nothing stopping going out with best come around saying sorry daddy's gonna show how be 'cause missing you'd better keep coming would health case haven't heard baby drew looks fake smile want needing everything should i'll bet she's beautiful girl talks about got have live without laugh funny can't even anyone he's says finally wonder knows reason teardrops guitar only keeps wishing star car singing don't know why do walks can breathe? goes perfectly kind flawless wish she'd hold tight give her look lucky home alone light his down maybe some sleep tonight enough break heart taken need fall into what ask still trying figure what's this road walking through rain though who feels own strong wrong life world wearing sleeve feeling today sunshine need? tomorrow's mystery yeah okay mission ready fly easily take very start fight feel somethin' wanted rainy ending given day walk away ain't use defending words will now sittin' thinkin' i've been anywhere cold walls paint them shade gray stood loving wished great story mess dreamer nerve adore did damn honey cried wouldn't told nobody died every condescending countin' scars you've made went between lines nowhere tried less traveled seems work few times am right? try better? let's view outside looking lot lonely places knew part too late helped notices until anything oh-oh doesn't beauty face mirror thinking pretty true baby; losing water's high jumping letting cry; might golden tied together undone guess givin' extra change hoping end pocket leaves penny price pay goodbye cory's are jungle smiles; whispers songs window girls corner they does know? piece love; someone looked leads door stay cory finds highlight taking pictures save make conversation breath hey gets daydream least front beautiful? na strange used sing smiles flowers yesterday found chance moment weakness yes should've thought twice 'fore known word 'bout (get me) shouldn't asking myself why? beggin' forgiveness feet cryin' things honestly expect same? past oh-whoa resist before worth it? she this? seven were nine shine sky lights our daddies joke two us growing falling mamas smiled rolled their house backyard tree beat bigger block wide dared kiss ran kids well sixteen suddenly wasn't believed we'd creek beds turned a.m. riding next slamming doors instead kissing goodnight stayed till morning years spot town knee walked aisle whole came where met many we'll rock babies porch after eighty-seven; eighty-nine ridin' shotgun hair seat one-hand steering wheel other something wrong? screen sneakin' tapping we're phone talk real slow mama date; man amen play again walkin' steps trampled lost thrown hallway lovin' almost notice roses note album listened waited along good laughs askin' grabbed pen an napkin wrote friday field behind yard painting sometimes listen crickets side wanna ground matter half small-town living isn't hide secrets or deepest fears anybody else she'll stop stare whenever wantin' miracle unbelievable invisible fire inside help shadows open you.  ...
# [109, 373, 110, 42, 111, 43, 374, 375, 112, 376, 377, 378, 14, 379, 44, 45, 4, 373, 113, 15, 380, 114, 15, 381, 46, 15, 382, 383, 44, 47, 15, 384, 115, 385, 386, 387, 388, 116, 45, 48, 4, 117, 118, 49, 389, 390, 50, 391, 392, 48, 119, 110, 51, 52, 393, 16, 14, 394, 44, 391, 395, 120, 121, 7, 122, 396, 397, 4, 398, 7, 122, 111, 399, 400, 110, 17, 52, 401, 14, 50, 45, 392, 110, 402, 26, 15, 403, 387, 110, 404, 121, 7, 122, 405, 4, 398, 7, 122, 44, 406, 123, 407, 122, 115, 111, 27, 387, 53, 408, 48, 111, 409, 410, 43, 411, 121, 7, 122, 396, 397, 4, 398, 7, 122, 115, 8, 412, 413, 15, 414, 115, 415, 48, 416, 124, 44, 7, 417, 54, 14, 55, 8, 26, 44, 120, 46, 15, 418, 419, 111, 125, 126, 15, 420, 44, 7, 28, 421, 422, 127, 423, 56, 128, 424, 425, 14, 394, 18, 50, 15, 406, 426, 48, 427, 56, 387, 50, 115, 44, 128, 129, 14, 130, 121, 7, 122, 396, 397, 4, 398, 7, 122, 111, 399, 400, 110, 17, 52, 401, 14, 50, 45, 392, 110, 402, 26, 15, 403, 387, 110, 404, 121, 7, 122, 405, 4, 398, 7, 122, 44, 406, 123, 407, 122, 115, 111, 27, 387, 53, 408, 48, 111, 409, 410, 43, 411, 121, 7, 122, 396, 397, 4, 398, 7, 122, 115, 8, 48, 131, 56, 57, 110, 132, 51, 428, 119, 131, 429, 387, 53, 430, 48, 431, 15, 420, 432, 387, 53, 433, 48, 110, 132, 133, 44, 434, 421, 126, 121, 7, 122, 396, 397, 4, 398, 7, 122, 111, 399, 400, 435, 434, 436, 53, 437, 387, 4, 398, 18, 438, 7, 56, 14, 44, 439, 121, 7, 122, 405, 4, 398, 7, 122, 44, 406, 123, 407, 122, 115, 111, 27, 387, 53, 408, 48, 111, 409, 410, 43, 411, 121, 7, 122, 396, 397, 4, 398, 7, 122, 115, 8, 1, 122, 115, 8, 19, 109, 373, 110, 42, 111, 43, 374, 375, 112, 376, 377, 378, 14, 379, 44, 45, 4, 373, 113, 15, 380, 440, 110, 441, 4, 134, 135, 111, 442, 443, 4, 444, 7, 20, 445, 136, 446, 7, 447, 9, 20, 8, 29, 21, 48, 448, 53, 137, 44, 131, 449, 48, 450, 113, 138, 7, 451, 30, 139, 4, 58, 452, 110, 42, 4, 140, 44, 453, 409, 454, 383, 7, 28, 455, 8, 456, 141, 15, 457, 458, 142, 459, 143, 116, 460, 29, 461, 8, 462, 15, 463, 387, 50, 111, 464, 51, 144, 465, 144, 131, 466, 141, 114, 467, 468, 14, 469, 431, 22, 51, 57, 415, 131, 114, 470, 54, 471, 111, 472, 431, 145, 146, 8, 422, 147, 5, 148, 50, 115, 53, 473, 137, 48, 139, 7, 474, 149, 475, 150, 14, 8, 111, 476, 477, 151, 7, 152, 150, 434, 59, 478, 4, 140, 44, 453, 409, 454, 383, 7, 28, 455, 8, 456, 141, 15, 457, 458, 142, 459, 143, 116, 460, 29, 461, 8, 462, 15, 463, 387, 50, 111, 464, 51, 144, 465, 144, 131, 466, 141, 114, 467, 468, 14, 469, 48, 139, 141, 60, 8, 479, 61, 153, 18, 14, 445, 478, 62, 56, 149, 54, 63, 59, 143, 57, 53, 480, 478, 4, 140, 44, 453, 409, 454, 383, 7, 28, 455, 8, 456, 141, 15, 457, 458, 142, 459, 143, 116, 460, 29, 461, 8, 462, 15, 463, 387, 50, 111, 464, 51, 46, 481, 7, 482, 64, 4, 459, 459, 140, 44, 453, 409, 454, 383, 7, 28, 455, 8, 456, 141, 15, 457, 458, 142, 459, 143, 116, 460, 29, 461, 8, 462, 15, 463, 387, 50, 111, 464, 51, 144, 465, 144, 131, 466, 141, 114, 467, 468, 14, 469, 469, 469, 469, 10, 469, 114, 467, 468, 14, 469, 10, 469, 483, 484, 116, 8, 4, 154, 15, 155, 29, 109, 451, 55, 44, 4, 485, 48, 131, 486, 156, 44, 52, 487, 59, 157, 488, 489, 158, 44, 159, 109, 490, 491, 48, 489, 160, 156, 44, 4, 161, 14, 492, 493, 483, 490, 14, 8, 4, 494, 478, 128, 114, 29, 495, 120, 4, 162, 163, 55, 496, 121, 497, 148, 8, 109, 498, 497, 29, 46, 20, 497, 499, 160, 18, 118, 4, 164, 139, 109, 500, 497, 50, 4, 122, 491, 116, 45, 497, 110, 501, 57, 110, 502, 387, 111, 503, 110, 504, 133, 44, 505, 8, 506, 387, 15, 506, 507, 497, 110, 400, 46, 110, 508, 4, 153, 165, 65, 31, 32, 4, 66, 483, 509, 452, 8, 67, 109, 448, 44, 4, 162, 166, 48, 49, 109, 510, 29, 511, 110, 512, 115, 513, 4, 514, 4, 447, 59, 515, 61, 167, 390, 516, 517, 390, 50, 518, 20, 168, 46, 376, 158, 374, 48, 31, 489, 519, 478, 497, 110, 501, 57, 110, 502, 387, 111, 503, 110, 504, 133, 44, 505, 8, 506, 387, 15, 506, 507, 497, 110, 400, 46, 110, 508, 4, 153, 165, 65, 31, 32, 4, 66, 29, 4, 456, 68, 520, 144, 4, 436, 5, 110, 69, 157, 112, 521, 468, 33, 48, 522, 135, 523, 524, 169, 478, 497, 110,  ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [[0.03035413 0.10455312 0.03063519 0.01152009]
#  [0.10455312 0.03063519 0.01152333 0.03090756]
#  [0.03063519 0.01152333 0.03091625 0.01180107]
#  ...
#  [0.01405284 0.01405284 0.01405284 0.00168587]
#  [0.01405284 0.01405284 0.00168634 0.03399831]
#  [0.01405284 0.00168634 0.03400787 1.        ]]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputLayer (InputLayer)        [(None, 3)]          0           []
#
#  layer1 (Dense)                 (None, 1000)         4000        ['inputLayer[0][0]']
#
#  layer2 (Dense)                 (None, 1000)         1001000     ['layer1[0][0]']
#
#  branchedLayer1 (Dense)         (None, 1000)         1001000     ['layer2[0][0]']
#
#  branchedLayer2 (Dense)         (None, 1000)         1001000     ['layer2[0][0]']
#
#  w1output (Dense)               (None, 1)            1001        ['layer2[0][0]']
#
#  w2output (Dense)               (None, 1)            1001        ['branchedLayer1[0][0]']
#
#  w3output (Dense)               (None, 1)            1001        ['branchedLayer2[0][0]']
#
# ==================================================================================================
# Total params: 3,010,003
# Trainable params: 3,010,003
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0961 - w1output_loss: 0.0320 - w2output_loss: 0.0321 - w3output_loss: 0.0321
# Epoch 00001: loss improved from inf to 0.09611, saving model to models.h5
# 3246/3246 [==============================] - 162s 50ms/step - loss: 0.0961 - w1output_loss: 0.0320 - w2output_loss: 0.0321 - w3output_loss: 0.0321 - lr: 0.0010
# Epoch 2/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0958 - w1output_loss: 0.0319 - w2output_loss: 0.0319 - w3output_loss: 0.0319
# Epoch 00002: loss improved from 0.09611 to 0.09576, saving model to models.h5
# 3246/3246 [==============================] - 161s 50ms/step - loss: 0.0958 - w1output_loss: 0.0319 - w2output_loss: 0.0319 - w3output_loss: 0.0319 - lr: 0.0010
# Epoch 3/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0957 - w1output_loss: 0.0319 - w2output_loss: 0.0319 - w3output_loss: 0.0319
# Epoch 00003: loss improved from 0.09576 to 0.09565, saving model to models.h5
# 3246/3246 [==============================] - 164s 50ms/step - loss: 0.0957 - w1output_loss: 0.0319 - w2output_loss: 0.0319 - w3output_loss: 0.0319 - lr: 0.0010
# Epoch 4/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0952 - w1output_loss: 0.0317 - w2output_loss: 0.0317 - w3output_loss: 0.0317
# Epoch 00004: loss improved from 0.09565 to 0.09523, saving model to models.h5
# 3246/3246 [==============================] - 161s 50ms/step - loss: 0.0952 - w1output_loss: 0.0317 - w2output_loss: 0.0317 - w3output_loss: 0.0317 - lr: 0.0010
# Epoch 5/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0948 - w1output_loss: 0.0316 - w2output_loss: 0.0316 - w3output_loss: 0.0316
# Epoch 00005: loss improved from 0.09523 to 0.09479, saving model to models.h5
# 3246/3246 [==============================] - 162s 50ms/step - loss: 0.0948 - w1output_loss: 0.0316 - w2output_loss: 0.0316 - w3output_loss: 0.0316 - lr: 0.0010
# Epoch 6/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0944 - w1output_loss: 0.0316 - w2output_loss: 0.0314 - w3output_loss: 0.0314
# Epoch 00006: loss improved from 0.09479 to 0.09446, saving model to models.h5
# 3246/3246 [==============================] - 162s 50ms/step - loss: 0.0945 - w1output_loss: 0.0316 - w2output_loss: 0.0314 - w3output_loss: 0.0314 - lr: 0.0010
# Epoch 7/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0943 - w1output_loss: 0.0315 - w2output_loss: 0.0314 - w3output_loss: 0.0314
# Epoch 00007: loss improved from 0.09446 to 0.09427, saving model to models.h5
# 3246/3246 [==============================] - 161s 50ms/step - loss: 0.0943 - w1output_loss: 0.0315 - w2output_loss: 0.0314 - w3output_loss: 0.0314 - lr: 0.0010
# Epoch 8/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0941 - w1output_loss: 0.0315 - w2output_loss: 0.0313 - w3output_loss: 0.0313
# Epoch 00008: loss improved from 0.09427 to 0.09409, saving model to models.h5
# 3246/3246 [==============================] - 155s 48ms/step - loss: 0.0941 - w1output_loss: 0.0315 - w2output_loss: 0.0313 - w3output_loss: 0.0313 - lr: 0.0010
# Epoch 9/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0940 - w1output_loss: 0.0314 - w2output_loss: 0.0313 - w3output_loss: 0.0313
# Epoch 00009: loss improved from 0.09409 to 0.09400, saving model to models.h5
# 3246/3246 [==============================] - 148s 46ms/step - loss: 0.0940 - w1output_loss: 0.0314 - w2output_loss: 0.0313 - w3output_loss: 0.0313 - lr: 0.0010
# Epoch 10/10
# 3245/3246 [============================>.] - ETA: 0s - loss: 0.0937 - w1output_loss: 0.0313 - w2output_loss: 0.0312 - w3output_loss: 0.0312
# Epoch 00010: loss improved from 0.09400 to 0.09365, saving model to models.h5
# 3246/3246 [==============================] - 148s 46ms/step - loss: 0.0937 - w1output_loss: 0.0313 - w2output_loss: 0.0312 - w3output_loss: 0.0312 - lr: 0.0010
# [0.030635188308038224, 0.011523327712197863, 0.030916245081506467] [0.1544106] [0.18372989] [0.1841675]
# [0.011523327712197863, 0.030916245081506467, 0.011804384485666104] [0.10751048] [0.10163737] [0.10287811]
# [0.030916245081506467, 0.011804384485666104, 0.10483417650365374] [0.07771695] [0.08123964] [0.08095835]
# [0.011804384485666104, 0.10483417650365374, 0.10511523327712198] [0.08011276] [0.08488561] [0.08446202]
# [0.10483417650365374, 0.10511523327712198, 0.03119730185497471] [0.15659367] [0.18312472] [0.1838629]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
model = keras. models.load_model("models.h5")

# numpy for dealing with arrays
import numpy as np

# math for rounding
import math

# FUNCTIONS:
# function that returns outputs from model
# potentially will have more functions from neural network
# rounding function
def round (num):
  num+=0.5
  num=math.floor(num)
  return num

####################
#   Prepare Data   #
####################

# open lyric file with data
file = open("folklore.txt", "r", encoding = "utf8")
lines=[]


# CREATE DICTIONARY and prepare dataset
# add words to variable
for i in file:
  lines.append(i)

data = ' '.join(lines)

# remove any unnecessary characters - leaving in '\n', newline character will be useful to consider as its own word
data=data.replace('"','').replace(',','')
data = data.lower()

# remove any repeats - need to create index so only one of each word is needed
z = []
for w in data.split():
  if w not in z:
    z.append(w)

dictionary = ' '.join(z)

# use keras tokenizer to create a dictionary of all words
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts([dictionary])

print (dictionary)
# save the tokenizer for later - use pickle.dump()

# convert the lyrics to numbers based on dictionary index
sequence_data = tokenizer.texts_to_sequences([data])[0]

print (sequence_data)
# store sequences of words (previous three words + word) in a list
sequences = []

for i in range (1, len(sequence_data)):
  words = sequence_data [i-3:i]
  sequences.append (words)

#sequences = np.array(sequences)

#scale inputs so that they are in between 0 and 1
scaler=MinMaxScaler()

scaler.fit(sequences[2:len(sequences)])
sequences=scaler.transform(sequences[2:len(sequences)])

print (sequences)
#print (sequences)

# create 3 input variables and 1 and output variable
x = []
y = []

count=0
# loop through each sequence
for i in sequences[2:len(sequences)]:
  # store previous 3 word in their own input variables, current word in output
  # this will be used for training
  x.append([])
  x[count].append(i[0])
  x[count].append(i[1])
  x[count].append(i[2])
  #y.append(i[3])
  count+=1

print (x1)

#convert to numpy array
#x1 = np.array(x1)
#x2 = np.array(x2)
#x3 = np.array(x3)
#y = np.array (y)


# run predictions with test portion of data
predictions = model.predict(x)

print (predictions)
predictions=np.reshape(predictions,(-1,3))
predictions=scaler.inverse_transform(predictions)
print (predictions)

roundedP=[]
for i in range(len(predictions)):
  roundedP.append([])
  for j in range(len(predictions[i])):
    roundedP[i].append(round(predictions[i][j]))
print (roundedP)
newWord=tokenizer.sequences_to_texts(roundedP)
print (newWord)

print (data[2],newWord[0])

"""
word1=predictions[0][0]
word2=predictions[0][1]
word3=predictions[0][2]

word1 = tokenizer.sequences_to_texts(word1)
word2 = tokenizer.sequences_to_texts(word1)
word3 = tokenizer.sequences_to_texts(word1)

ogword = []
# loop through each sequence
#for i in sequences[2:len(sequences)]:
  # store previous 3 word in their own input variables, current word in output
  # this will be used for training
  #ogword.append(tokenizer.sequences_to_texts[i])

for i in range (0,5):
  print (ogword[i],word1[i],word2[i],word3[i])
"""
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5acd5a74b44a> in <module>()
#      24
#      25 # open lyric file with data
# ---> 26 file = open("folklore.txt", "r", encoding = "utf8")
#      27 lines=[]
#      28
#
# FileNotFoundError: [Errno 2] No such file or directory: 'folklore.txt'
